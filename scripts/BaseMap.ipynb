# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
nodes = np.array([
    [-400, 300],
    [-400, 200],
    [-400, 0],
    [-400, -200],
    
    [-300, 100],
    [-300, 0],
    [-300, -100],
    
    [-200, 300],
    [-200, 200],
    [-200, 100],
    [-200, -100],
    
    [-200, -180],
    [-200, -220],
    [-220, -200],
    [-180, -200],
    
    [-100, 100],
    [-100, 0],
    [-100, -100],
    
    
    [0, 300],
    [0, 200],
    [0, 100],
    [0, 0],
    [0, -100],
    [0, -200],
    
    
    [100, 300],
    [100, 200],
    [100, 100],
    [100, 0],
    [100, -100],
    [100, -200],
    
    
    [200, 300],
    [200, 200],
    [200, 100],
    [200, 0],
    [200, -100],
    [200, -200],
    
    
    [300, 300],
    [300, 200],
    [300, 100],
    [300, 0],
    [300, -100],
    [300, -200],
    
    [-200, -300],
    [200, -300],
    [250, -300],
    [400, -150],
    [400, 250],
    [250, 400],
    
    
    [200, 460],
    [200, 400],
    [200, 340],
    
    
    [100, 460],
    [100, 400],
    [100, 340],
    
    [0, 400],
    [0, 340],
    
    
    [-400, 340],
    
    [200, -400],
    [150, -450],
    
    
    [120, -420],
    [70, -370],
    
    [-350, -420],
    [-400, -370],
    
    [100, -450],
    [50, -500],
    
    [-350, -450],
    [-400, -500],
])
edges = np.array([
    [0, 1],
    [1, 2],
    [2, 3],
    
    [4, 5],
    [5, 6],
    
    
    [7, 8],
    [8, 9],
    
    [10, 11],
    [11, 14],
    [14, 12],
    [12, 13],
    [13, 11],
    
    [0, 7],
    [1, 8],
    [2, 5],
    [4, 9],
    [6, 10],
    [3, 13],
    
    
    [15, 16],
    [16, 17],
    
    [9, 15],
    [10, 17],
    
    [18, 19],
    [19, 20],
    [20, 21],
    [21, 22],
    [22, 23],
    
    
    [7, 18],
    [8, 19],
    [16, 21],
    [14, 23],
    
    [24, 25],
    [25, 26],
    [26, 27],
    [27, 28],
    [28, 29],
    
    [18, 24],
    [19, 25],
    [20, 26],
    [21, 27],
    [22, 28],
    [23, 29],
    
    
    [30, 31],
    [31, 32],
    [32, 33],
    [33, 34],
    [34, 35],
    
    [24, 30],
    [25, 31],
    [26, 32],
    [27, 33],
    [28, 34],
    [29, 35],
    
    [36, 37],
    [37, 38],
    [38, 39],
    [39, 40],
    [40, 41],
    
    
    [30, 36],
    [31, 37],
    [32, 38],
    [33, 39],
    [34, 40],
    [35, 41],
    
    [12, 42],
    [42, 43],
    [43, 44],
    [44, 45],
    [45, 46],
    [46, 47],
    
    
    
    [48, 49],
    [49, 50],
    
    [47, 49],
    
    [51, 52],
    [52, 53],
    
    
    [48, 51],
    [49, 52],
    [50, 53],
    
    [54, 55],
    
    [52, 54],
    [55, 53],
    
    
    [55, 56],
    [56, 0],
    
    
    [43, 57],
    [57, 58],
    [58, 59],
    [59, 60],
    
    [61, 62],
    
    
    [60, 62],
    [59, 61],
    
    [58, 63],
    
    
    [63, 64],
    
    [65, 66],
    
    [65, 63],
    [66, 64],
])

plt.plot(nodes[:, 0], nodes[:, 1], "o")

for i in range(0, nodes.shape[0]):
    plt.text(nodes[i, 0] + 10, nodes[i, 1] + 10, str(i))

for i in range(0, edges.shape[0]):
    p1 = edges[i, 0]
    p2 = edges[i, 1]
    plt.plot([nodes[p1, 0], nodes[p2, 0]], [nodes[p1, 1], nodes[p2, 1]])

# %%
for i in range(0, nodes.shape[0]):
    print(nodes[i, 0], nodes[i, 1])
print("#")
for i in range(0, edges.shape[0]):
    print(edges[i, 0], edges[i, 1])
# Out:
# -400 300
# -400 200
# -400 0
# -400 -200
# -300 100
# -300 0
# -300 -100
# -200 300
# -200 200
# -200 100
# -200 -100
# -200 -180
# -200 -220
# -220 -200
# -180 -200
# -100 100
# -100 0
# -100 -100
# 0 300
# 0 200
# 0 100
# 0 0
# 0 -100
# 0 -200
# 100 300
# 100 200
# 100 100
# 100 0
# 100 -100
# 100 -200
# 200 300
# 200 200
# 200 100
# 200 0
# 200 -100
# 200 -200
# 300 300
# 300 200
# 300 100
# 300 0
# 300 -100
# 300 -200
# -200 -300
# 200 -300
# 250 -300
# 400 -150
# 400 250
# 250 400
# 200 460
# 200 400
# 200 340
# 100 460
# 100 400
# 100 340
# 0 400
# 0 340
# -400 340
# 200 -400
# 150 -450
# 120 -420
# 70 -370
# -350 -420
# -400 -370
# 100 -450
# 50 -500
# -350 -450
# -400 -500
# #
# 0 1
# 1 2
# 2 3
# 4 5
# 5 6
# 7 8
# 8 9
# 10 11
# 11 14
# 14 12
# 12 13
# 13 11
# 0 7
# 1 8
# 2 5
# 4 9
# 6 10
# 3 13
# 15 16
# 16 17
# 9 15
# 10 17
# 18 19
# 19 20
# 20 21
# 21 22
# 22 23
# 7 18
# 8 19
# 16 21
# 14 23
# 24 25
# 25 26
# 26 27
# 27 28
# 28 29
# 18 24
# 19 25
# 20 26
# 21 27
# 22 28
# 23 29
# 30 31
# 31 32
# 32 33
# 33 34
# 34 35
# 24 30
# 25 31
# 26 32
# 27 33
# 28 34
# 29 35
# 36 37
# 37 38
# 38 39
# 39 40
# 40 41
# 30 36
# 31 37
# 32 38
# 33 39
# 34 40
# 35 41
# 12 42
# 42 43
# 43 44
# 44 45
# 45 46
# 46 47
# 48 49
# 49 50
# 47 49
# 51 52
# 52 53
# 48 51
# 49 52
# 50 53
# 54 55
# 52 54
# 55 53
# 55 56
# 56 0
# 43 57
# 57 58
# 58 59
# 59 60
# 61 62
# 60 62
# 59 61
# 58 63
# 63 64
# 65 66
# 65 63
# 66 64
